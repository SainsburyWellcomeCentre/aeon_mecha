# %%
cd ..
# Out:
# C:\Users\thinh\Documents\TN-Vathes\ProjectAeon\aeon

# %%
import datajoint as dj

# %%
from aeon.aeon_pipeline import lab, experiment, subject, tracking
# Out:
# Connecting ttngu207@tutorial-db.datajoint.io:3306

# %%
dj.Diagram(experiment) - 1 + dj.Diagram(tracking)

# %%
experiment.TimeBlock.describe();
# Out:
# # A recording period corresponds to an N-hour data acquisition
# -> experiment.Experiment
# time_block_start     : datetime(3)                  # datetime of the start of this recorded TimeBlock
# ---
# time_block_end       : datetime(3)                  # datetime of the end of this recorded TimeBlock

# %%
tracking.schema.drop()
# Out:
# Proceed to delete entire schema `ttngu207_aeon_tracking`? [yes, No]: yes

# %%
experiment.schema.drop()
# Out:
# Proceed to delete entire schema `ttngu207_aeon_experiment`? [yes, No]: yes
